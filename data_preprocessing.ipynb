# %%
import pandas as pd

# %%
# Load the dataset
data = "all_locations_daily_weather_data.csv"
df = pd.read_csv(data)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55128 entries, 0 to 55127
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       55128 non-null  object
#  1   latitude                   55128 non-null  float64
#  2   longitude                  55128 non-null  float64
#  3   weather_code               55128 non-null  float64
#  4   temperature_2m_max         55128 non-null  float64
#  5   temperature_2m_min         55128 non-null  float64
#  6   temperature_2m_mean        55128 non-null  float64
#  7   apparent_temperature_max   55128 non-null  float64
#  8   apparent_temperature_min   55128 non-null  float64
#  9   apparent_temperature_mean  55128 non-null  float64
#  10  sunrise                    55128 non-null  int64
#  11  sunset                     55128 non-null  int64
#  12  daylight_duration          55128 non-null  float64
# ...

# %%
df.head()
# Out:
#                         date   latitude   longitude  weather_code  \
# 0  1999-12-31 13:00:00+00:00 -37.785587  144.939758           3.0
# 1  2000-01-01 13:00:00+00:00 -37.785587  144.939758           1.0
# 2  2000-01-02 13:00:00+00:00 -37.785587  144.939758          53.0
# 3  2000-01-03 13:00:00+00:00 -37.785587  144.939758          63.0
# 4  2000-01-04 13:00:00+00:00 -37.785587  144.939758          51.0
#
#    temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0             19.1105            9.560500            14.729251
# 1             21.7105            9.610500            15.910500
# 2             27.8605           12.160501            19.006330
# 3             17.3605           12.310500            14.270916
# 4             16.8605           12.410501            14.518834
#
#    apparent_temperature_max  apparent_temperature_min  \
# 0                 16.202528                  7.653307
# 1                 23.871464                  7.853928
# ...

# %%
# Out:
# 🔹 Missing Values:
# Series([], dtype: int64)
